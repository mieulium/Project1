# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Is there a distinct correlation between the students taking SAT or ACT?

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import scipy.stats as stats 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
read_act_2017 = pd.read_csv('act_2017.csv')
act_2017 = pd.DataFrame(read_act_2017)

read_sat_2017 = pd.read_csv('sat_2017.csv')
sat_2017 = pd.DataFrame(read_sat_2017)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
act_2017.head(30)
# Out:
#                    state  act_2017_participation  act_2017_english  \
# 1                Alabama                     100              18.9
# 2                 Alaska                      65              18.7
# 3                Arizona                      62              18.6
# 4               Arkansas                     100              18.9
# 5             California                      31              22.5
# 6               Colorado                     100              20.1
# 7            Connecticut                      31              25.5
# 8               Delaware                      18              24.1
# 9   District of Columbia                      32              24.4
# 10               Florida                      73              19.0
# 11               Georgia                      55              21.0
# 12                Hawaii                      90              17.8
# 13                 Idaho                      38              21.9
# ...

# %%
sat_2017.head(30)
# Out:
#                    state  sat_2017_participation  \
# 0                Alabama                       5
# 1                 Alaska                      38
# 2                Arizona                      30
# 3               Arkansas                       3
# 4             California                      53
# 5               Colorado                      11
# 6            Connecticut                     100
# 7               Delaware                     100
# 8   District of Columbia                     100
# 9                Florida                      83
# 10               Georgia                      61
# 11                Hawaii                      55
# 12                 Idaho                      93
# 13              Illinois                       9
# 14               Indiana                      63
# 15                  Iowa                       2
# 16                Kansas                       4
# 17              Kentucky                       4
# ...

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
#act_2017.isnull()
#sat_2017.isnull()

# %%
#print(act_2017.duplicated(['State']))
#print(sat_2017.duplicated(['State']))

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
#print(act_2017)
#print(sat_2017)

#sat_2017.dtypes
#sat_2017.shape
#act_2017.dtypes
#act_2017.shape

sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: -
#
# _**Data**_
# - Data does not have any empty values
# - SAT data only has 2 test columns, while ACT has 4
# - SAT data does not include Nation average
# - SAT data has logging error (ind20 Math incomplete)
# - ACT data has errors (ind51 has string in Composite scores, ind21 Science logging error)
# - ACT participation contains non-int values (remove the %)
#
#
# _**Statistical Data**_
# - Each of the dataframe consists of two kinds of variable types:
#     - **ACT**
#         - Object: State, Participation, Composite
#         - Float: English, Math, Reading, Science
#
#     - **SAT**
#         - Object: State, Participation
#         - Integer: Evidence-Based Reading and Writing, Math, Total
#
# - The SAT 2017 dataframe has 5 categories and 51 rows, while the ACT 2017 dataframe has 7 categories and 52 rows of data.
#
# - Both dataframes do not have any null values.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: No. Though there is no null cell found in the data, SAT data contains one less row of data, and the ACT data contains some errors in it.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# Answer:
#
# EBRW = Evidence-based Reading and Writing
#
# **SAT**:
#
# |Stats|EBRW|Math|Total|
# |---|---|---|---|
# |Min|482|52|651|
# |Max|644|651|1295|
#
# *Anomalies found*: SAT has a min score of 200 per section, therfore Math can't have a minimum of 52.
#
# **ACT:**
#
# |Stats|English|Math|Reading|Science|
# |---|---|---|---|---|
# |Min|16.3|18.0|18.1|2.3|
# |Max|25.5|25.3|26.0|24.9|
#
# *Anomalies found*: The min for Science in ACT is at 2, which is possible, but may be worth checking. The Composite scores are also in the wrong data type.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#SAT editing
sat_weird = sat_2017[(sat_2017['Math']<200)] #finding out which entry is erroneous - Maryland (index 20)
sat_2017.at[20, 'Math'] = 524 #changing entry value to accurate value - 524 on the data source
sat_2017.describe() # double checking if all stats resume normalcy
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
#ACT editing
act_weird = act_2017[(act_2017['Science']< 10)] # finding out which entry is erroneous in Science - Maryland (index 21)
act_2017.at[21, 'Science'] = 22.2 # changing entry value to accurate value - 22.2 on the data source
act_2017.describe() # double checking if all stats resume normalcy
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.423077
# std     2.332132   1.963602   2.048672   1.708871
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#SAT and ACT Data Types
print('SAT Data Types\n', sat_2017.dtypes,'\n\nACT Data Types\n', act_2017.dtypes)
# Out:
# SAT Data Types
#  State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# ACT Data Types
#  State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# **Answer:** Composite for ACT is an object type series. Participation is objects in both data sets but are meant to be numerical.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act_2017.Composite.tail() # finding out why Composite is under object type - index 51 has an additional x in the entry

act_2017.Composite.apply(lambda x: float(x) , convert_dtype=True) #change type to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2ccc49d542de> in <module>
#       1 act_2017.Composite.tail() # finding out why Composite is under object type - index 51 has an additional x in the entry
#       2
# ----> 3 act_2017.Composite.apply(lambda x: float(x) , convert_dtype=True) #change type to float
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-25-2ccc49d542de> in <lambda>(x)
# ...

# %%
# changing participation types
act_2017.Participation.apply(lambda x: int(x), convert_dtype = True) #changing type to int
sat_2017.Participation.apply(lambda x: int(x), convert_dtype = True) #changing type to int

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#changing misentered value in composite
act_2017.at[51, 'Composite'] = 20.2
act_2017['Composite'][51]
# Out:
# 20.2

# %%
# removing extra characters in Participation rates
act_2017['Participation'] = act_2017['Participation'].apply(lambda x: x.replace("%",""))
sat_2017['Participation'] = sat_2017['Participation'].apply(lambda x: x.replace("%",""))
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National            60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           100     18.9  18.4     19.7     19.4      19.2
# 2    Alaska            65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona            62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           100     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# re-typing edited columns
act_2017['Composite'] = act_2017['Composite'].apply(lambda x: float(x) , convert_dtype=True) #
act_2017['Participation'] = act_2017['Participation'].apply(lambda x: int(x), convert_dtype = True)
sat_2017['Participation'] = sat_2017['Participation'].apply(lambda x: int(x), convert_dtype = True)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#printing out the types of variables:
print('SAT\n', sat_2017.dtypes,'\n\nACT\n', act_2017.dtypes)
# Out:
# SAT
#  State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# ACT
#  State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#creating a dictionary of keys (old names) and values (new name)
#act column name dictionary
rename_act_dict_2017 = {}
for i in act_2017.columns:
    if i == 'State':
        rename_act_dict_2017[i] = i.lower()
    else:
        rename_act_dict_2017[i] = 'act_2017_'+ i.lower()
rename_act_dict_2017
# Out:
# {'State': 'state',
#  'Participation': 'act_2017_participation',
#  'English': 'act_2017_english',
#  'Math': 'act_2017_math',
#  'Reading': 'act_2017_reading',
#  'Science': 'act_2017_science',
#  'Composite': 'act_2017_composite'}

# %%
#sat column rename dictionary
rename_sat_dict_2017 = {}
for i in sat_2017.columns:
    if i == 'State':
        rename_sat_dict_2017[i] = i.lower()
    else:
        rename_sat_dict_2017[i] = 'sat_2017_'+ i.lower().replace(" ","").replace("-","")
rename_sat_dict_2017
# Out:
# {'State': 'state',
#  'Participation': 'sat_2017_participation',
#  'Evidence-Based Reading and Writing': 'sat_2017_evidencebasedreadingandwriting',
#  'Math': 'sat_2017_math',
#  'Total': 'sat_2017_total'}

# %%
#renaming the df columns
sat_2017 = sat_2017.rename(columns = rename_sat_dict_2017)
act_2017 = act_2017.rename(columns = rename_act_dict_2017)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %%
#looking at the types of data in df
print(act_2017.dtypes, "\n\n", sat_2017.dtypes)
# Out:
# state                      object
# act_2017_participation      int64
# act_2017_english          float64
# act_2017_math             float64
# act_2017_reading          float64
# act_2017_science          float64
# act_2017_composite        float64
# dtype: object
#
#  state                                      object
# sat_2017_participation                      int64
# sat_2017_evidencebasedreadingandwriting     int64
# sat_2017_math                               int64
# sat_2017_total                              int64
# dtype: object

# %% [markdown]
# ## ACT 2017
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT|States of America with results|
# |act_2017_participation|int|ACT|Participation rate of students in 2017 ACT per state|
# |act_2017_english|float|ACT|Average score of the state in English in 2017 ACT|
# |act_2017_math|float|ACT|Average score of the state in Math in 2017 ACT|
# |act_2017_reading|float|ACT|Average score of the state in Reading in 2017 ACT|
# |act_2017_science|float|ACT|Average score of the state in Science in 2017 ACT|
# |act_2017_composite|float|ACT|Average Composite score (total score) of the state in 2017 ACT|
#
# ## SAT 2017
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|States of America with SAT results|
# |sat_2017_participation|int|SAT|Participation rate of students in 2017 SAT per state|
# |sat_2017_evidencebasedreadingandwriting|int|SAT|Average score of the state in Evidence-Based Reading and Writing in 2017 SAT|
# |sat_2017_math|int|SAT|Average score of the state in Math in 2017 SAT|
# |sat_2017_total|int|SAT|Average total score of the state in 2017 SAT|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# iterating through the indexes to see if there is an additional row that does not match with the other dataset
for x in act_2017.state: # chose act first as act has more rows
    count = 0
    for s in sat_2017.state: 
        if x == s:
            count += 1
    if count != 1:
        print(x, "is an extra row in ACT 2017 data")

act_2017[act_2017['state'] == "National"] # to locate where National is on (index 0)

act_2017 = act_2017.drop(0) #dropping National from the dataset 

act_2017.head()
# Out:
# National is an extra row in ACT 2017 data
#         state  act_2017_participation  act_2017_english  act_2017_math  \
# 1     Alabama                     100              18.9           18.4
# 2      Alaska                      65              18.7           19.8
# 3     Arizona                      62              18.6           19.8
# 4    Arkansas                     100              18.9           19.0
# 5  California                      31              22.5           22.7
#
#    act_2017_reading  act_2017_science  act_2017_composite
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#merge act and sat scores in 2017 together
act_sat_2017 = pd.merge(act_2017, sat_2017, how='inner', on = 'state')

act_sat_2017.columns
# Out:
# Index(['state', 'act_2017_participation', 'act_2017_english', 'act_2017_math',
#        'act_2017_reading', 'act_2017_science', 'act_2017_composite',
#        'sat_2017_participation', 'sat_2017_evidencebasedreadingandwriting',
#        'sat_2017_math', 'sat_2017_total'],
#       dtype='object')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#saving data as a new csv file
act_sat_2017.to_csv('../code/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# importing 2018 data
sat_2018 = pd.read_csv("../code/sat_2018.csv")
act_2018 = pd.read_csv("../code/act_2018.csv")

# %%
# looking at the dataset stats
print('SAT 2018 \n')
print(sat_2018.info(),'\n \n ACT 2018 \n')
print(act_2018.info())
# Out:
# SAT 2018
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#
#  ACT 2018
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
# State            53 non-null object
# Participation    47 non-null float64
# Composite        53 non-null float64
# English          53 non-null float64
# Math             53 non-null float64
# Reading          53 non-null float64
# Science          53 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB
# None

# %%
# finding duplicated rows in the dataset
act_2018.State.value_counts() #National is duplicated
# Out:
# National                2
# Nevada                  1
# Vermont                 1
# West Virginia           1
# New York                1
# Minnesota               1
# Wisconsin               1
# Oregon                  1
# Colorado                1
# Maine                   1
# Florida                 1
# Ohio                    1
# New Mexico              1
# Alaska                  1
# Kentucky                1
# Alabama                 1
# Louisiana               1
# Michigan                1
# Pennsylvania            1
# Utah                    1
# Arizona                 1
# New Jersey              1
# Kansas                  1
# Georgia                 1
# Indiana                 1
# Illinois                1
# New Hampshire           1
# Arkansas                1
# Texas                   1
# Tennessee               1
# Wyoming                 1
# Rhode Island            1
# Virginia                1
# Mississippi             1
# Hawaii                  1
# ...

# %% [markdown]
# ## Primary data stats:
#
# **SAT**
# - SAT 2018 results have 51 rows and 5 columns
# - State and Participation columns are object columns
# - Evidence-Based Reading and Writing, Math and Total columns are all int columns
#
# **ACT**
# - data obtained from https://magoosh.com/hs/act/2016/average-act-score-by-state/
# - ACT 2018 results have 53 rows and 7 columns
# - State and Participation are all object columns
# - English, Math, Reading and Science columns are all int columns
# - There are 6 null values in ACT 2018 results
# - There are 1 duplicated entry ('National') in the dataset
#
#
# ## Completion of data:
# - Data is not complete for ACT 2018, but is complete for SAT 2018.
# - Additional data will be added into the dataset using https://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf

# %%
# data adding
act_2018[act_2018['Participation'].isnull()] # finding out which have missing values
# Out:
#              State  Participation  Composite  English  Math  Reading  Science
# 18       Louisiana            NaN       19.2     19.0  18.5     19.6     19.1
# 27        National            NaN       20.8     20.2  20.5     21.3     20.7
# 34  North Carolina            NaN       19.1     18.0  19.3     19.5     19.2
# 37        Oklahoma            NaN       19.3     18.4  18.8     20.1     19.4
# 39    Pennsylvania            NaN       23.5     23.3  23.2     24.0     23.1
# 52        National            NaN       20.8     20.2  20.5     21.3     20.7

# %%
 #locating where 'National' rows is found on the df
act_2018.loc[act_2018['State'] == 'National'] #index 27 and 52 belongs to National
# Out:
#        State  Participation  Composite  English  Math  Reading  Science
# 27  National            NaN       20.8     20.2  20.5     21.3     20.7
# 52  National            NaN       20.8     20.2  20.5     21.3     20.7

# %%
# matching state results to the results on https://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf
act_2018.at[18, 'Participation'] = 100
act_2018.at[27, 'Participation'] = 55
act_2018.at[34, 'Participation'] = 100
act_2018.at[37, 'Participation'] = 100
act_2018.at[39, 'Participation'] = 20
act_2018.at[52, 'Participation'] = 55

print(act_2018[act_2018['Participation'].isnull()]) # double checking if there are any missing values left
act_2018.info()
# Out:
# Empty DataFrame
# Columns: [State, Participation, Composite, English, Math, Reading, Science]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
# State            53 non-null object
# Participation    53 non-null float64
# Composite        53 non-null float64
# English          53 non-null float64
# Math             53 non-null float64
# Reading          53 non-null float64
# Science          53 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# finding which dataset has extra columns 
for x in act_2018.State: # chose act first as act has more rows
    count = 0
    for s in sat_2018.State: 
        if x == s:
            count += 1
    if count != 1:
        print(x, "is an extra row in ACT 2018 data") # National found has having 2 rows
        
act_2018.loc[act_2018.State == 'National'] # National found in index 27 and 52

# drop National rows
act_2018 = act_2018.drop(27).drop(52)
# Out:
# National is an extra row in ACT 2018 data
# National is an extra row in ACT 2018 data

# %%
#act_2018.reset_index()
act_2018.head()
# Out:
#         State  Participation  Composite  English  Math  Reading  Science
# 0     Alabama          100.0       19.1     18.9  18.3     19.6     19.0
# 1      Alaska           33.0       20.8     19.8  20.6     21.6     20.7
# 2     Arizona           66.0       19.2     18.2  19.4     19.5     19.2
# 3    Arkansas          100.0       19.4     19.1  18.9     19.7     19.4
# 4  California           27.0       22.7     22.5  22.5     23.0     22.1

# %%
# making dictionary for both datasets to rename column text
rename_act_dict_2018 = {}
for i in act_2018.columns:
    if i == 'State':
        rename_act_dict_2018[i] = i.lower()
    else:
        rename_act_dict_2018[i] = 'act_2018_'+ i.lower()
print(rename_act_dict_2018)

rename_sat_dict_2018 = {}
for i in sat_2018.columns:
    if i == 'State':
        rename_sat_dict_2018[i] = i.lower()
    else:
        rename_sat_dict_2018[i] = 'sat_2018_'+ i.lower().replace(" ","").replace("-","")
print(rename_sat_dict_2018)

#renaming column text

sat_2018 = sat_2018.rename(columns = rename_sat_dict_2018)
act_2018 = act_2018.rename(columns = rename_act_dict_2018)
print(act_2018)
print(sat_2018)
# Out:
# {'State': 'state', 'Participation': 'act_2018_participation', 'Composite': 'act_2018_composite', 'English': 'act_2018_english', 'Math': 'act_2018_math', 'Reading': 'act_2018_reading', 'Science': 'act_2018_science'}
# {'State': 'state', 'Participation': 'sat_2018_participation', 'Evidence-Based Reading and Writing': 'sat_2018_evidencebasedreadingandwriting', 'Math': 'sat_2018_math', 'Total': 'sat_2018_total'}
#                    state  act_2018_participation  act_2018_composite  \
# 0                Alabama                   100.0                19.1
# 1                 Alaska                    33.0                20.8
# 2                Arizona                    66.0                19.2
# 3               Arkansas                   100.0                19.4
# 4             California                    27.0                22.7
# 5               Colorado                    30.0                23.9
# 6            Connecticut                    26.0                25.6
# ...

# %%
# changing types of participation for SAT 2018
sat_2018.sat_2018_participation.apply(lambda x: int(x), convert_dtype = True) # sat_2018 have error with presence of % symbol
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-d5b786596018> in <module>
#       1 # changing types of participation for SAT 2018
# ----> 2 sat_2018.sat_2018_participation.apply(lambda x: int(x), convert_dtype = True) # sat_2018 have error with presence of % symbol
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-49-d5b786596018> in <lambda>(x)
#       1 # changing types of participation for SAT 2018
# ...

# %%
# removing % from participation
sat_2018['sat_2018_participation'] = sat_2018.sat_2018_participation.apply(lambda x: float(x.replace("%","")))

print(act_2018.act_2018_participation.head())
print(sat_2018.sat_2018_participation.head())
# Out:
# 0    100.0
# 1     33.0
# 2     66.0
# 3    100.0
# 4     27.0
# Name: act_2018_participation, dtype: float64
# 0     6.0
# 1    43.0
# 2    29.0
# 3     5.0
# 4    60.0
# Name: sat_2018_participation, dtype: float64

# %%
#doublechecking SAT data
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                                      51 non-null object
# sat_2018_participation                     51 non-null float64
# sat_2018_evidencebasedreadingandwriting    51 non-null int64
# sat_2018_math                              51 non-null int64
# sat_2018_total                             51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#doublechecking ACT data
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 7 columns):
# state                     51 non-null object
# act_2018_participation    51 non-null float64
# act_2018_composite        51 non-null float64
# act_2018_english          51 non-null float64
# act_2018_math             51 non-null float64
# act_2018_reading          51 non-null float64
# act_2018_science          51 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## ACT 2018
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT|States of America with results|
# |act_2018_participation|int|ACT|Participation rate of students in 2018 ACT per state|
# |act_2018_english|float|ACT|Average score of the state in English in 2018 ACT|
# |act_2018_math|float|ACT|Average score of the state in Math in 2018 ACT|
# |act_2018_reading|float|ACT|Average score of the state in Reading in 2018 ACT|
# |act_2018_science|float|ACT|Average score of the state in Science in 2018 ACT|
# |act_2018_composite|float|ACT|Average Composite score (total score) of the state in 2018 ACT|
#
# ## SAT 2018
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|States of America with SAT results|
# |sat_2018_participation|int|SAT|Participation rate of students in 2018 SAT per state|
# |sat_2018_evidencebasedreadingandwriting|int|SAT|Average score of the state in Evidence-Based Reading and Writing in 2018 SAT|
# |sat_2018_math|int|SAT|Average score of the state in Math in 2018 SAT|
# |sat_2018_total|int|SAT|Average total score of the state in 2018 SAT|

# %%
#merge 2018 results
act_sat_2018 = pd.merge(act_2018, sat_2018, how='inner', on = 'state')

# %%
# check merge
act_sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
# state                                      51 non-null object
# act_2018_participation                     51 non-null float64
# act_2018_composite                         51 non-null float64
# act_2018_english                           51 non-null float64
# act_2018_math                              51 non-null float64
# act_2018_reading                           51 non-null float64
# act_2018_science                           51 non-null float64
# sat_2018_participation                     51 non-null float64
# sat_2018_evidencebasedreadingandwriting    51 non-null int64
# sat_2018_math                              51 non-null int64
# sat_2018_total                             51 non-null int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# merge 2017 and 2018 data
final = pd.merge(act_sat_2017, act_sat_2018, how='inner', on = 'state')
# reset_index
final.reset_index()
# Out:
#     index                 state  act_2017_participation  act_2017_english  \
# 0       0               Alabama                     100              18.9
# 1       1                Alaska                      65              18.7
# 2       2               Arizona                      62              18.6
# 3       3              Arkansas                     100              18.9
# 4       4            California                      31              22.5
# 5       5              Colorado                     100              20.1
# 6       6           Connecticut                      31              25.5
# 7       7              Delaware                      18              24.1
# 8       8  District of Columbia                      32              24.4
# 9       9               Florida                      73              19.0
# 10     10               Georgia                      55              21.0
# 11     11                Hawaii                      90              17.8
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final_trps = final.describe().T
final_trps
# Out:
#                                          count         mean        std    min  \
# act_2017_participation                    51.0    65.254902  32.140842    8.0
# act_2017_english                          51.0    20.931373   2.353677   16.3
# act_2017_math                             51.0    21.182353   1.981989   18.0
# act_2017_reading                          51.0    22.013725   2.067271   18.1
# act_2017_science                          51.0    21.431373   1.724818   18.2
# act_2017_composite                        51.0    21.519608   2.020695   17.8
# sat_2017_participation                    51.0    39.803922  35.276632    2.0
# sat_2017_evidencebasedreadingandwriting   51.0   569.117647  45.666901  482.0
# sat_2017_math                             51.0   556.882353  47.121395  468.0
# sat_2017_total                            51.0  1126.098039  92.494812  950.0
# act_2018_participation                    51.0    61.647059  34.080976    7.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#function to calculate standard deviation
def stdev(x):
    varsum = 0
    for i in x:
        varsum += (i - x.mean())**2
    return ((1/(x.count()))*(varsum))**0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# dictionary comprehension to create dictionary for standard deviations of each column
sd = {x.name:stdev(x) for x in [final[i] for i in final.columns if (final[i].dtype=='float64') or (final[i].dtype=='int64')]}
sd
# Out:
# {'act_2017_participation': 31.824175751231806,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7078240020539415,
#  'act_2017_composite': 2.000786081581989,
#  'sat_2017_participation': 34.92907076664508,
#  'sat_2017_evidencebasedreadingandwriting': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_participation': 33.745194881997506,
#  'act_2018_composite': 2.0855261815801147,
#  'act_2018_english': 2.4222536143202795,
#  'act_2018_math': 2.015707255555717,
#  'act_2018_reading': 2.145891884510421,
#  'act_2018_science': 1.8516885484833543,
#  'sat_2018_participation': 36.946619223539415,
#  'sat_2018_evidencebasedreadingandwriting': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
#using describe() to find stdev
final.describe()
# Out:
#        act_2017_participation  act_2017_english  act_2017_math  \
# count               51.000000         51.000000      51.000000
# mean                65.254902         20.931373      21.182353
# std                 32.140842          2.353677       1.981989
# min                  8.000000         16.300000      18.000000
# 25%                 31.000000         19.000000      19.400000
# 50%                 69.000000         20.700000      20.900000
# 75%                100.000000         23.300000      23.100000
# max                100.000000         25.500000      25.300000
#
#        act_2017_reading  act_2017_science  act_2017_composite  \
# count         51.000000         51.000000           51.000000
# mean          22.013725         21.431373           21.519608
# std            2.067271          1.724818            2.020695
# min           18.100000         18.200000           17.800000
# 25%           20.450000         19.950000           19.800000
# ...

# %%
#using the same list comprehension to find SD using numpy
sd = {x.name: np.std(x) for x in [final[i] for i in final.columns if (final[i].dtype=='float64') or (final[i].dtype=='int64')]}
sd
# Out:
# {'act_2017_participation': 31.824175751231806,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7078240020539415,
#  'act_2017_composite': 2.000786081581989,
#  'sat_2017_participation': 34.92907076664508,
#  'sat_2017_evidencebasedreadingandwriting': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_participation': 33.745194881997506,
#  'act_2018_composite': 2.0855261815801147,
#  'act_2018_english': 2.4222536143202795,
#  'act_2018_math': 2.015707255555717,
#  'act_2018_reading': 2.145891884510421,
#  'act_2018_science': 1.8516885484833543,
#  'sat_2018_participation': 36.946619223539415,
#  'sat_2018_evidencebasedreadingandwriting': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %% [markdown]
# Answer: The calculated fuction does not match with pandas .describe() function, but matches with numpy's std method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year? sort values
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code

# sort_values by top
final.sort_values(by='sat_2017_participation', ascending = False).head() 
final.sort_values(by='sat_2017_participation', ascending = True).head()
# Out:
#                    state  act_2017_participation  act_2017_english  \
# 8   District of Columbia                      32              24.4
# 22              Michigan                      29              24.1
# 6            Connecticut                      31              25.5
# 7               Delaware                      18              24.1
# 29         New Hampshire                      18              25.4
#
#     act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 8            23.5              24.9              23.5                24.2
# 22           23.7              24.5              23.8                24.1
# 6            24.6              25.6              24.6                25.2
# 7            23.4              24.8              23.6                24.1
# 29           25.1              26.0              24.9                25.5
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# ...

# %%
final.sort_values(by='act_2017_participation', ascending = False).head(20) 
final.sort_values(by='act_2017_participation', ascending = True).head()
# Out:
#              state  act_2017_participation  act_2017_english  act_2017_math  \
# 0          Alabama                     100              18.9           18.4
# 17        Kentucky                     100              19.6           19.4
# 49       Wisconsin                     100              19.7           20.4
# 44            Utah                     100              19.5           19.9
# 42       Tennessee                     100              19.5           19.2
# 40  South Carolina                     100              17.5           18.6
# 36        Oklahoma                     100              18.5           18.8
# 33  North Carolina                     100              17.8           19.3
# 28          Nevada                     100              16.3           18.0
# 26         Montana                     100              19.0           20.2
# 24     Mississippi                     100              18.2           18.1
# ...

# %%
final.sort_values(by='sat_2018_participation', ascending = False).head(10) 
final.sort_values(by='sat_2018_participation', ascending = True).head()
# Out:
#            state  act_2017_participation  act_2017_english  act_2017_math  \
# 34  North Dakota                      98              19.0           20.4
# 50       Wyoming                     100              19.4           19.8
# 41  South Dakota                      80              20.7           21.5
# 27      Nebraska                      84              20.9           20.9
# 49     Wisconsin                     100              19.7           20.4
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 34              20.5              20.6                20.3
# 50              20.8              20.6                20.2
# 41              22.3              22.0                21.8
# 27              21.9              21.5                21.4
# 49              20.6              20.9                20.5
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 34                       2                                      635
# ...

# %%
final.sort_values(by='act_2018_participation', ascending = False).head(25) 
final.sort_values(by='act_2018_participation', ascending = True).head()
# Out:
#             state  act_2017_participation  act_2017_english  act_2017_math  \
# 19          Maine                       8              24.2           24.0
# 39   Rhode Island                      21              24.0           23.3
# 29  New Hampshire                      18              25.4           25.1
# 7        Delaware                      18              24.1           23.4
# 38   Pennsylvania                      23              23.4           23.4
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 19              24.8              23.7                24.3
# 39              24.7              23.4                24.0
# 29              26.0              24.9                25.5
# 7               24.8              23.6                24.1
# 38              24.2              23.3                23.7
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 19                      95                                      513
# ...

# %%
#composite/total scores

final[final.act_2017_composite == final.act_2017_composite.agg(max)]
final[final.act_2017_composite == final.act_2017_composite.agg(min)]
final[final.sat_2017_total == final.sat_2017_total.agg(max)]#.sat_2017_total
final[final.sat_2017_total == final.sat_2017_total.agg(min)]#.sat_2017_total
final[final.act_2018_composite == final.act_2018_composite.agg(max)]
final[final.act_2018_composite == final.act_2018_composite.agg(min)]
final[final.sat_2018_total == final.sat_2018_total.agg(max)]
final[final.sat_2018_total == final.sat_2018_total.agg(min)]
# Out:
#                   state  act_2017_participation  act_2017_english  \
# 8  District of Columbia                      32              24.4
#
#    act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 8           23.5              24.9              23.5                24.2
#
#    sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 8                     100                                      482
#
#    sat_2017_math  ...  act_2018_participation  act_2018_composite  \
# 8            468  ...                    32.0                23.6
#
#    act_2018_english  act_2018_math  act_2018_reading  act_2018_science  \
# 8              23.7           22.7              24.4              23.0
#
#    sat_2018_participation  sat_2018_evidencebasedreadingandwriting  \
# 8                    92.0                                      497
#
#    sat_2018_math  sat_2018_total
# 8            480             977
#
# [1 rows x 21 columns]

# %%
#Participation change
final[final.act_2017_participation == final.act_2017_participation.agg(max)].sort_values(by='act_2018_participation')
final[final.act_2018_participation == final.act_2018_participation.agg(max)].sort_values(by='act_2017_participation')
final[final.sat_2017_participation == final.sat_2017_participation.agg(max)].sort_values(by='sat_2018_participation')
final[final.sat_2018_participation == final.sat_2018_participation.agg(max)].sort_values(by='sat_2017_participation')
# Out:
#           state  act_2017_participation  act_2017_english  act_2017_math  \
# 5      Colorado                     100              20.1           20.3
# 12        Idaho                      38              21.9           21.8
# 6   Connecticut                      31              25.5           24.6
# 7      Delaware                      18              24.1           23.4
# 22     Michigan                      29              24.1           23.7
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 5               21.2              20.9                20.8
# 12              23.0              22.1                22.3
# 6               25.6              24.6                25.2
# 7               24.8              23.6                24.1
# 22              24.5              23.8                24.1
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 5                       11                                      606
# ...

# %%
# >50% participation both tests in a year
final[(final.act_2017_participation >= 50) & (final.sat_2017_participation >= 50)]
final[(final.act_2018_participation >= 50) & (final.sat_2018_participation >=50)]
# Out:
#              state  act_2017_participation  act_2017_english  act_2017_math  \
# 9          Florida                      73              19.0           19.4
# 10         Georgia                      55              21.0           20.9
# 11          Hawaii                      90              17.8           19.2
# 33  North Carolina                     100              17.8           19.3
# 40  South Carolina                     100              17.5           18.6
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 9               21.0              19.4                19.8
# 10              22.0              21.3                21.4
# 11              19.2              19.3                19.0
# 33              19.6              19.3                19.1
# 40              19.1              18.9                18.7
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 9                       83                                      520
# ...

# %%
# <50% participation both tests in a year
final[(final.act_2017_participation < 50) & (final.sat_2017_participation < 50)]
final[(final.act_2018_participation < 50) & (final.sat_2018_participation < 50)]
# Out:
#      state  act_2017_participation  act_2017_english  act_2017_math  \
# 1   Alaska                      65              18.7           19.8
# 37  Oregon                      40              21.2           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 1               20.4              19.9                19.8
# 37              22.4              21.7                21.8
#
#     sat_2017_participation  sat_2017_evidencebasedreadingandwriting  \
# 1                       38                                      547
# 37                      43                                      560
#
#     sat_2017_math  ...  act_2018_participation  act_2018_composite  \
# 1             533  ...                    33.0                20.8
# 37            548  ...                    42.0                21.3
#
#     act_2018_english  act_2018_math  act_2018_reading  act_2018_science  \
# 1               19.8           20.6              21.6              20.7
# ...

# %% [markdown]
# ## Answers
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#         - Max @ 100%: DC, Michigan, Connecticut, Delaware
#         - Min @ 2%: North Dakota, Mississippi, Iowa
#     - 2018 SAT?
#         - Max @ 100%: Colorado, Connecticut, Delaware, Michigan, Idaho
#         - Min @ 2%: North Dakota
#     - 2017 ACT?
#         - Max @ 100%:  Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolinam, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado, Arkansas
#         - Min @ 8%: Maine
#     - 2018 ACT?
#         - Max @ 100%: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolinam, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming, Arkansas
#         - Min @ 7%: Maine
#
#
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#         - Total:
#             - Max @ 1295: Minnesota
#             - Min @ 950: DC
#     - 2018 SAT?
#         - Total:
#             - Max @ 1298: Minnesota
#             - Min @ 977: DC
#     - 2017 ACT?
#         - Composite:
#             - Max @ 25.5: New Hampshire <-
#             - Min @ 17.8: Nevada
#     - 2018 ACT?
#         - Composite:
#             - Max @ 25.6: Connecticut <-
#             - Min @ 17.7: Nevada
#
#
# - Do any states with 100% participation on a given test have a rate change year-to-year? sort values
#     - 2017 SAT?/2018 SAT?
#         - Decrease
#             - DC: 100% to 92% <-
#         - Increase
#             - Colorado: 11% to 100% <-
#             - Idaho: 93% to 100% <-
#     - 2017 ACT?/2018 ACT?
#         - Decrease
#             - Colorado: 100% to 30% <-
#             - Minnesota: 100% to 99%
#         - Increase
#             - Ohio: 75% to 100%
#             - Nebraska: 84% to 100%
#
#
# - Do any states show have >50% participation on *both* tests either year?
#     - 2017
#         - Florida: 73% ACT, 83% SAT <-
#         - Georgia: 55% ACT, 61% SAT
#         - Hawaii: 90% ACT, 55% SAT <-
#         - South Carolina: 100% ACT, 50% SAT <-
#     - 2018
#         - Florida: 66% ACT, 56% SAT
#         - Georgia: 53% ACT, 70% SAT <-
#         - Hawaii: 89% ACT, 56% SAT <-
#         - North Carolina: 100% ACT, 52% SAT <-
#         - South Carolina: 100% ACT, 55% SAT <-
#
# ** Personal Qn**
# - Do any states have <50% participation on *both* tests either year?
#     - 2017
#         - Oregon: 40% ACT, 43% SAT
#     - 2018
#         - Alaska: 33% ACT, 43% SAT
#         - Oregon: 42% ACT, 48% SAT

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig, ax = plt.subplots(figsize=(20,20)) 

#setting mask up 
mask = np.zeros_like(final.corr())
mask[np.triu_indices_from(mask)] = True

#setting heatmap
sns.heatmap(final.corr(), mask = mask, linewidths=.5, ax=ax, annot = True, cmap="Greens", annot_kws={"size": 17});
ax.get_ylim()
ax.set_ylim(20, 0)
ax.set_title('Correlations between test scores and participation')
# Out:
# Text(0.5, 1, 'Correlations between test scores and participation')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (20,20)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins = 20, alpha = 1, density = True) # feel free to add more settings
        ax[i].set(xlabel= list_of_xlabels, ylabel= 'Frequency', title = list_of_titles[i])
        ax[i].axvline(final[list_of_columns[i]].mean(), color='yellow')
        # Set titles, labels, etc here for each subplot

# %%
final['act_2017_participation'].mode()
# Out:
# 0    100
# dtype: int64

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates
participation_list = ['act_2017_participation', 'act_2018_participation', 'sat_2017_participation', 'sat_2018_participation']
participation_title = ['ACT 2017 Participation', 'ACT 2018 Participation', 'SAT 2017 Participation', 'SAT 2018 Participation']


subplot_histograms(final, participation_list, participation_title,'percentage')

# %% [markdown]
# ## Interpretation of participation histograms
#
# - ACT scores are more skewed to the left while SAT scores are more skewed to the right for both years.
# - Mode in ACT participation for both years are at 100%, while the mode for SAT participation is close to 0%

# %%
#math histograms
math_list = ['act_2017_math', 'act_2018_math', 'sat_2017_math', 'sat_2018_math']
math_title = ['ACT 2017 Math', 'ACT 2018 Math', 'SAT 2017 Math', 'SAT 2018 Math']
subplot_histograms(final, math_list, math_title,'score')

# %% [markdown]
# ## Interpretation of Math Histogram scores
# - all graphs are all right skewed
# - all graphs are more evenly distributed as compared to Participation values.

# %%
#reading histogram
reading_list = ['act_2017_reading', 'act_2018_reading', 'sat_2017_evidencebasedreadingandwriting', 'sat_2018_evidencebasedreadingandwriting']
reading_title = ['ACT 2017 Reading', 'ACT 2018 Reading', 'SAT 2017 Evidence-based reading and writing', 'SAT 2018 Evidence-based reading and writing']
subplot_histograms(final, reading_list, reading_title,'score')

# %% [markdown]
# ## Interpretation of the Reading scores
# - Both ACT Reading scores are both right skewed.
# - SAT 2017 scores are right skewed, while SAT 2018 scores are left skewed.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def scatter_plots(x, y, title):
    plt.figure(figsize=(15,10))
    sns.regplot(x, y, data = final).set_title(title)

# %%
# math scores (2017)
scatter_plots(final.act_2017_math, final.sat_2017_math, 'Plot of ACT and SAT Math Scores (2017)')

# %% [markdown]
# ## Observations of 2017 Math Scores using scatterplot
# - General downward trend

# %%
#reading vs EBRW scores (2017)
scatter_plots(final.act_2017_reading, final.sat_2017_evidencebasedreadingandwriting, 'Plot of SAT and ACT Reading/EBRW Scores (2017)')

# %% [markdown]
# ## Observations of Reading/Evidence based reading and writing
# - general downward trend between ACT Reading vs SAT Evidence based reading and writing

# %%
# SAT vs. ACT total/composite scores for 2017
scatter_plots(final.act_2017_composite,final.sat_2017_total, 'Plot of SAT and ACT scores (2017)')

# %% [markdown]
# ## Observations of ACT 2017 composite vs SAT 2017 total scores
# - generally downward trend

# %%
# Total scores for SAT 2017 vs. 2018
scatter_plots(final.sat_2017_total, final.sat_2018_total, 'Plot of SAT scores (2017 & 2018)')

# %%
## Composite scores for ACT 2017 vs. 2018
scatter_plots(final.act_2017_composite, final.act_2018_composite, 'Plot of ACT scores (2017 & 2018)')

# %% [markdown]
# ## Observations from ACT 2017 vs ACT 2018 scatterplot
# - a positive relationship, where the scores are almost one to one

# %%
# participation ACT 2017 and ACT 2018
scatter_plots(final.act_2017_participation, final.act_2018_participation, 'Plot of ACT participation (2017, 2018)')

# %%
#finding out the linear regression equation
stats.linregress(final.act_2017_participation, final.act_2018_participation)
# Out:
# LinregressResult(slope=0.9746552700669187, intercept=-1.953975270249117, rvalue=0.9191708840307006, pvalue=1.825475347116378e-21, stderr=0.05966195414306225)

# %% [markdown]
# ## Observations of ACT 2017 and 2018 Participation rates:
# - Participation has a relationship of almost y=x gradient

# %%
# participation SAT 2017 and SAT 2018
scatter_plots(final.sat_2017_participation, final.sat_2018_participation, 'Plot of SAT participation (2017, 2018)')

# %%
#finding the linear regression equation
stats.linregress(final.sat_2017_participation, final.sat_2018_participation)
# Out:
# LinregressResult(slope=0.9252903264841527, intercept=8.914914455630786, rvalue=0.874762886907544, pvalue=4.918185663965603e-17, stderr=0.07321993354458707)

# %% [markdown]
# ## Observations of SAT 2017 and 2018 Participation rates:
# - Participation has a relationship of almost y=x gradient, but has a larger intercept than of ACT 2017 and 2018 participation.
#     - Possibility that there might be a slight increase in participation?

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# box plot for act composite scores

final[['act_2017_composite', 'act_2018_composite']].boxplot(figsize = (15,10))
plt.title('Boxplots of ACT composite scores (2017, 2018)', fontsize = 20)
plt.xticks(fontsize= 14)
plt.yticks(fontsize = 15)
plt.ylabel('Scores', fontsize = 20)
plt.xlabel('ACT sections (2017, 2018)', fontsize = 20)
# Out:
# Text(0.5, 0, 'ACT sections (2017, 2018)')

# %%
stats.ttest_ind(final.act_2017_composite, final.act_2018_composite)
# Out:
# Ttest_indResult(statistic=0.08155560824978775, pvalue=0.93516311388039)

# %% [markdown]
# ## Observations
# - 2018 composite mean is lower than the 2017 composite mean. However with t-test the means are not significantly different

# %%
# box plot for sat total scores
final[['sat_2017_total', 'sat_2018_total']].boxplot(figsize = (10,10))
plt.title('Boxplots of SAT Total Scores (2017, 2018)', size = 20)
plt.xticks(fontsize=14)
plt.yticks(fontsize = 15)
plt.ylabel('Scores', fontsize = 20)
plt.xlabel('SAT Total Scores (2017, 2018)', fontsize = 20)
# Out:
# Text(0.5, 0, 'SAT Total Scores (2017, 2018)')

# %%
stats.ttest_ind(final.sat_2017_total, final.sat_2018_total)
# Out:
# Ttest_indResult(statistic=0.32888697491988567, pvalue=0.7429288943265793)

# %% [markdown]
# ## Interpretations
# - 2018 has a lower mean but smaller IQR.
# - The means are not significantly different.

# %%
#boxplot for all act individual sections
final[['act_2017_english', 'act_2018_english','act_2017_math', 'act_2018_math', \
       'act_2017_reading', 'act_2018_reading', 'act_2017_science','act_2018_science']].boxplot(figsize = (22,15))
plt.title('Boxplots of ACT section scores (2017, 2018)',size = 20)
plt.xticks(fontsize=17)
plt.yticks(fontsize = 18)
plt.ylabel('Scores', fontsize = 20)
plt.xlabel('ACT sections', fontsize = 20)
# Out:
# Text(0.5, 0, 'ACT sections')

# %%
print(stats.ttest_ind(final.act_2017_english, final.act_2018_english))
print(stats.ttest_ind(final.act_2017_math, final.act_2018_math))
print(stats.ttest_ind(final.act_2017_reading, final.act_2018_reading))
print(stats.ttest_ind(final.act_2017_science, final.act_2018_science))
# Out:
# Ttest_indResult(statistic=-0.11961970126362943, pvalue=0.9050244010289329)
# Ttest_indResult(statistic=0.1429241656548978, pvalue=0.886637663501542)
# Ttest_indResult(statistic=-0.004675253997432277, pvalue=0.9962790146886391)
# Ttest_indResult(statistic=0.24217959311190373, pvalue=0.8091369828973366)

# %% [markdown]
# ## Interpretations
# - all sections show a tendency to have a lower mean in 2018, however the means are not significantly different.

# %%
#boxplot for all act individual sections
final[['sat_2017_evidencebasedreadingandwriting', 'sat_2018_evidencebasedreadingandwriting',\
       'sat_2017_math', 'sat_2018_math']].boxplot(figsize = (20,10))
plt.title('Boxplots of SAT section scores (2017, 2018)', size = 20)
plt.xticks(fontsize=14)
plt.yticks(fontsize = 15)
plt.ylabel('Scores', fontsize = 20)
plt.xlabel('SAT sections (2017, 2018)', fontsize = 20)
# Out:
# Text(0.5, 0, 'SAT sections (2017, 2018)')

# %%
print(stats.ttest_ind(final.sat_2017_evidencebasedreadingandwriting, final.sat_2018_evidencebasedreadingandwriting))
print(stats.ttest_ind(final.sat_2017_math, final.sat_2018_math))
# Out:
# Ttest_indResult(statistic=0.588642340555069, pvalue=0.557428492532448)
# Ttest_indResult(statistic=0.06886440276247592, pvalue=0.9452350680711727)

# %% [markdown]
# ## Interpretations
# - Though the means for 2018 SAT sections are lower consistently, they are not significantly different.

# %%
final.columns
# Out:
# Index(['state', 'act_2017_participation', 'act_2017_english', 'act_2017_math',
#        'act_2017_reading', 'act_2017_science', 'act_2017_composite',
#        'sat_2017_participation', 'sat_2017_evidencebasedreadingandwriting',
#        'sat_2017_math', 'sat_2017_total', 'act_2018_participation',
#        'act_2018_composite', 'act_2018_english', 'act_2018_math',
#        'act_2018_reading', 'act_2018_science', 'sat_2018_participation',
#        'sat_2018_evidencebasedreadingandwriting', 'sat_2018_math',
#        'sat_2018_total'],
#       dtype='object')

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#set state as index
finalstateind = final.set_index('state')
#print(finalstateind)
key = [col for col in finalstateind.columns if 'composite' in col]
compositedf = finalstateind[key]

# %%
participationkey = ['act_2017_participation', 'act_2018_participation', 'sat_2017_participation', 'sat_2018_participation']
participationdf = finalstateind[participationkey]

# %%
#100% ACT Part 1
country_ACT_full1= ['Wyoming', 'Wisconsin', 'Utah', 'Tennessee','South Carolina', 'Oklahoma', \
           'North Carolina', 'Nevada']

act100df1 = finalstateind.loc[country_ACT_full1]
act100df1 = act100df1[participationkey]
act100df1.plot.barh(figsize = (10,17))
plt.legend(loc = 'center right')
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('States', fontsize = 15)
plt.xticks(size=15)
plt.yticks(size=20)
plt.title('States with 100% ACT Participation (1)', size = 20)
# Out:
# Text(0.5, 1.0, 'States with 100% ACT Participation (1)')

# %%
country_ACT_full2= ['Montana','Missouri', 'Mississippi', 'Minnesota', 'Louisiana',\
          'Kentucky', 'Arkansas', 'Alabama']
act100df2 = finalstateind.loc[country_ACT_full2]
act100df2 = act100df2[participationkey]
act100df2.plot.barh(figsize = (10,17))
plt.legend(loc = 'center right')
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('States', fontsize = 15)
plt.xticks(size=15)
plt.yticks(size=20)
plt.title('States with 100% ACT Participation (2)', size = 20)
# Out:
# Text(0.5, 1.0, 'States with 100% ACT Participation (2)')

# %% [markdown]
# ## Interpretation:
# - All these states are known to have mandatory ACT testing for all high school students.
# - Special point of interest is North and South Carolina - still a near 50% SAT participation rate though ACT is mandatory (possible outflow of students taking the SATs to qualify for other state universities?)
#
# Cite: https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/

# %%
# 100% SAT
country_SAT_full= ['Michigan', 'Connecticut', 'Idaho', 'Delaware']
sat100df = finalstateind.loc[country_SAT_full]
sat100df = sat100df[participationkey]
sat100df.plot.barh(figsize = (15,10))
plt.legend(loc = 'center right')
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('States', fontsize = 15)
plt.xticks(size=15)
plt.yticks(size=20)
plt.title('States with 100% SAT Participation', size = 20)
# Out:
# Text(0.5, 1.0, 'States with 100% SAT Participation')

# %% [markdown]
# ## Interpretation:
# - Out of these 4, only 3 (Connecticut, Delaware and Michigan) are known to have mandatory SAT testing.
# - Idaho has a preference for SAT even though is known to subsidise the cost of both tests.
#
# Cite: https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe().T
# Out:
#                                          count         mean        std    min  \
# act_2017_participation                    51.0    65.254902  32.140842    8.0
# act_2017_english                          51.0    20.931373   2.353677   16.3
# act_2017_math                             51.0    21.182353   1.981989   18.0
# act_2017_reading                          51.0    22.013725   2.067271   18.1
# act_2017_science                          51.0    21.431373   1.724818   18.2
# act_2017_composite                        51.0    21.519608   2.020695   17.8
# sat_2017_participation                    51.0    39.803922  35.276632    2.0
# sat_2017_evidencebasedreadingandwriting   51.0   569.117647  45.666901  482.0
# sat_2017_math                             51.0   556.882353  47.121395  468.0
# sat_2017_total                            51.0  1126.098039  92.494812  950.0
# act_2018_participation                    51.0    61.647059  34.080976    7.0
# ...

# %%
#recalling SD
#sd
final.skew()
# Out:
# act_2017_participation                    -0.197989
# act_2017_english                           0.352660
# act_2017_math                              0.332683
# act_2017_reading                           0.269366
# act_2017_science                           0.239900
# act_2017_composite                         0.319810
# sat_2017_participation                     0.346450
# sat_2017_evidencebasedreadingandwriting    0.272693
# sat_2017_math                              0.365040
# sat_2017_total                             0.310903
# act_2018_participation                    -0.021916
# act_2018_composite                         0.281962
# act_2018_english                           0.371507
# act_2018_math                              0.269548
# act_2018_reading                           0.201361
# act_2018_science                           0.172383
# sat_2018_participation                     0.136228
# sat_2018_evidencebasedreadingandwriting    0.282300
# ...

# %%
# Shapiro Wilks test for normality
for col in final.columns:
    if col == 'state':
        None
    else:
        print('{} = {}'.format(col, stats.shapiro(final[col])))
# Out:
# act_2017_participation = (0.8398400545120239, 6.9784323386556935e-06)
# act_2017_english = (0.9486985802650452, 0.02782275155186653)
# act_2017_math = (0.9527901411056519, 0.041251927614212036)
# act_2017_reading = (0.9556081295013428, 0.05425470694899559)
# act_2017_science = (0.9653500914573669, 0.14097939431667328)
# act_2017_composite = (0.9499148726463318, 0.03126131370663643)
# sat_2017_participation = (0.8536623120307922, 1.649127807468176e-05)
# sat_2017_evidencebasedreadingandwriting = (0.920563280582428, 0.0022041318006813526)
# sat_2017_math = (0.9493668675422668, 0.029660698026418686)
# sat_2017_total = (0.9359506964683533, 0.008478053845465183)
# act_2018_participation = (0.8256993889808655, 3.0170992886269232e-06)
# act_2018_composite = (0.9495515823364258, 0.030190475285053253)
# act_2018_english = (0.9341007471084595, 0.007173534482717514)
# act_2018_math = (0.9506924748420715, 0.03368766978383064)
# act_2018_reading = (0.9529093503952026, 0.04173128679394722)
# ...

# %% [markdown]
# **Answers:**
#
# |Columns|Central Tendency|Spread (Stdev)|Skew|Normality (Shapiro Wilks)
# |----|----|----|----|----|
# |act_2017_participation|Mean not equal to median|31.824175751231806|-0.197989|Significant for non-normal distribution|
# |act_2017_english|Mean close to median|2.3304876369363363|0.352660|Significant for non-normal distribution|
# |act_2017_math|Mean close to median|1.9624620273436781|0.332683|Significant for non-normal distribution|
# |act_2017_reading|Mean close to median|2.0469029314842646|0.269366|Insignificant for non-normal distribution|
# |act_2017_science|Mean close to median|1.7078240020539415|0.239900|Insignificant for non-normal distribution|
# |act_2017_composite|Mean close to median|2.000786081581989|0.319810|Significant for non-normal distribution|
# |sat_2017_participation|Mean not equal to median|34.92907076664508|0.346450|Significant for non-normal distribution|
# |sat_2017_evidencebasedreadingandwriting|Median not equal to median|45.21697020437866|0.272693|Significant for non-normal distribution|
# |sat_2017_math|Mean not equal to median|46.65713364485503|0.365040|Significant for non-normal distribution|
# |sat_2017_total|Mean not equal to median|91.58351056778743|0.310903|Significant for non-normal distribution|
# |act_2018_participation|Mean not equal to median|33.745194881997506|-0.021916|Significant for non-normal distribution|
# |act_2018_english|Mean close to median|2.4222536143202795|0.371507|Significant for non-normal distribution|
# |act_2018_math|Mean not equal to median|2.015707255555717|0.269548|Significant for non-normal distribution|
# |act_2018_reading|Mean not equal to median|2.145891884510421|0.201361|Significant for non-normal distribution|
# |act_2018_science|Mean close to median|1.8516885484833543|0.172383|Significant for non-normal distribution|
# |act_2018_composite|Mean close to median|2.0855261815801147|0.281962|Significant for non-normal distribution|
# |sat_2018_participation|Mean not equal to median|36.946619223539415|0.136228|Significant for non-normal distribution|
# |sat_2018_evidencebasedreadingandwriting|Mean not equal to median|47.03460978357609|0.282300|Significant for non-normal distribution|
# |sat_2018_math|Mean not equal to median|47.30194550378352|0.530407|Significant for non-normal distribution|
# |sat_2018_total|Mean not equal to median|93.22742384464433|0.466432|Significant for non-normal distribution|

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, not all data in the dataset is normally distributed according to the Shapiro Wilks Test, except for 2017 ACT Reading and Science scores.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# ## Results from Shapiro Wilks Test
#
# ### ACT
# - 2017 Participation: Not Normal
# - 2017 English: Not Normal
# - 2017 Math: Not Normal
# - 2017 Reading: Normal
# - 2017 Science: Normal
# - 2017 Composite: Not Normal
# - 2018 Participation: Not Normal
# - 2018 English: Not Normal
# - 2018 Math: Not Normal
# - 2018 Reading: Not Normal
# - 2018 Science: Not Not Normal
# - 2018 Composite: Not Normal
#
# ### SAT
# - 2017 Participation: Not Normal
# - 2017 Evidence Based Reading and Writing: Not Normal
# - 2017 Math: Not Normal
# - 2017 Total: Not Normal
# - 2018 Participation: Not Normal
# - 2018 Evidence Based Reading and Writing: Not Normal
# - 2018 Math: Not Normal
# - 2018 Total: Not Normal

# %% [markdown]
# Answer: ACT Reading and Science (2017) showed a normal distribution. Estimates that are made from non-normally distributed data might be inaccurate.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# **Answer:** It is possible to conduct statistical inference between SAT and ACT participation rates as they both are looking at the same population of people from the same state. However, there will only be a limited amount of statistical inference that can be made as the data available lack granularity as it lacks actual numbers.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# **Answer:** No, as the tests taken are different, and thus it will not be an accurate comparison. In addition, the scale of both tests are different, and thus it will definitely present a significant difference of means between them.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
lin = stats.linregress(final.act_2017_reading, final.act_2017_science)
lin
# Out:
# LinregressResult(slope=0.821076924488654, intercept=3.3564105269919224, rvalue=0.9840971679099441, pvalue=1.9396704263002463e-38, stderr=0.021172226443567158)

# %%
scatter_plots(final.act_2017_reading, final.act_2017_science,'Relationship between ACT 2017 Reading and Science Scores')

# %% [markdown]
# ## Interpretation:
# - ACT 2017 Reading and Science shows a high correlation (r = 0.9840971679099441) and a significant positive linear relationship between both sections.
#     - equation: act_2017_science = (0.821076924488654)* act_2017_reading + 3.3564105269919224
# - possible implication: The sections might reflect a high correlation between sections due to literacy instead of actual prediction of scores.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# **Answer:** Some figures and interpretation done above in the additional plot section for 100% ACT and 100% SAT participation rates. Below shows three other states not covered that have a possible unique situation.

# %%
state_interest= ['Alaska', 'Colorado', 'Maine']
interestdf = finalstateind.loc[state_interest]
interestdf = interestdf[participationkey]
interestdf.plot.barh(figsize = (15,8))
plt.legend(loc = 'lower right')
plt.xlabel('Participation rate', fontsize=20)
plt.ylabel('States', fontsize = 15)
plt.xticks(size=15)
plt.yticks(size=20)
plt.title('States of Interest', size = 20)
# Out:
# Text(0.5, 1.0, 'States of Interest')

# %% [markdown]
# ## Interpretation
# - Colorado has a unique graph where it changed from 100% participation in ACT 2017 to 100% participation in SAT 2018.
#     - This is because there was a change in high school testing in 2017 from ACT to SAT.
#         Source: "https://www.testive.com/colorado-sat-change-2017/"
# - Alaska has a middling participation rate for both ACT and SAT.
#     - This is because there is no state preferred test for Alaska.
#         Source: " https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/"
# - Maine has a high SAT participation
#     - This is because the state has requires SAT.
#         Source: "https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/"
#         - However, Maine does not have 100% test participation in SAT
#             - Possibility: They might not be in the public school system

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ## Takeaways:
#    - There are less states participating fully in SATs as compared to ACTs
#        - It can be recommended that to improve participation rates, College Board can be encouraged to approach schools boards in states that do not have already require the SAT or ACT
#            - E.G Oregon
#                - Has consistently lower participation rates for both years for both tests
#                - Possible Strategy:
#                    - To cooperate with the state to provide subsidised testing as Oregon does not have a preferred test and subsidised test seems to be a major indicator of choice.

# %% [markdown]
# ## Additional details in the dataset might prove helpful
#    - Actual scores of each student
#    - Actual amount of students graduating that year
#    - Amount of test centres that are around
#    - State literacy rate
